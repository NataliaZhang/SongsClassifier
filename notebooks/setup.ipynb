# %% [markdown]
# # Set up

# %%
# Clone repo (run once per Colab session)
# !git clone https://github.com/NataliaZhang/SongsClassifier.git
# %cd SongsClassifier
# Out:
# /content/SongsClassifier

# %%
# TODO
